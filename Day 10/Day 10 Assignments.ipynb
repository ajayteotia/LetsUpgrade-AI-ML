# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.read_csv("general_data.csv")
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset = pd.read_csv("general_data.csv")

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
dataset.groupby(by="Attrition").size()
# Out:
# Attrition
# No     3699
# Yes     711
# dtype: int64

# %%
dataset.loc[dataset['Attrition'] == 'Yes']
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 6      28       Yes      Travel_Rarely  Research & Development
# 13     47       Yes         Non-Travel  Research & Development
# 28     44       Yes  Travel_Frequently  Research & Development
# 30     26       Yes      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4381   29       Yes      Travel_Rarely  Research & Development
# 4386   33       Yes      Travel_Rarely                   Sales
# 4388   33       Yes      Travel_Rarely                   Sales
# 4391   32       Yes      Travel_Rarely                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                   10          1  Life Sciences              1           2
# ...

# %%
dataset1 = dataset.loc[dataset['Attrition'] == 'Yes']

# %%
dataset1.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 1    31       Yes  Travel_Frequently  Research & Development
# 6    28       Yes      Travel_Rarely  Research & Development
# 13   47       Yes         Non-Travel  Research & Development
# 28   44       Yes  Travel_Frequently  Research & Development
# 30   26       Yes      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1[['Age','DistanceFromHome','Education','PercentSalaryHike','StandardHours']].describe()
# Out:
#               Age  DistanceFromHome   Education  PercentSalaryHike  \
# count  711.000000        711.000000  711.000000         711.000000
# mean    33.607595          9.012658    2.877637          15.481013
# std      9.675693          7.772368    1.014233           3.775289
# min     18.000000          1.000000    1.000000          11.000000
# 25%     28.000000          2.000000    2.000000          12.000000
# 50%     32.000000          7.000000    3.000000          14.000000
# 75%     39.000000         15.000000    4.000000          18.000000
# max     58.000000         29.000000    5.000000          25.000000
#
#        StandardHours
# count          711.0
# mean             8.0
# std              0.0
# min              8.0
# 25%              8.0
# 50%              8.0
# 75%              8.0
# max              8.0

# %%
dataset1[['TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']].describe()
# Out:
#        TotalWorkingYears  YearsAtCompany  YearsSinceLastPromotion  \
# count         709.000000      711.000000               711.000000
# mean            8.255289        5.130802                 1.945148
# std             7.164018        5.941598                 3.148633
# min             0.000000        0.000000                 0.000000
# 25%             3.000000        1.000000                 0.000000
# 50%             7.000000        3.000000                 1.000000
# 75%            10.000000        7.000000                 2.000000
# max            40.000000       40.000000                15.000000
#
#        YearsWithCurrManager
# count            711.000000
# mean               2.852321
# std                3.138918
# min                0.000000
# 25%                0.000000
# 50%                2.000000
# 75%                5.000000
# max               14.000000

# %%
dataset1[['Age','DistanceFromHome','Education','PercentSalaryHike','StandardHours']].mode()
# Out:
#    Age  DistanceFromHome  Education  PercentSalaryHike  StandardHours
# 0   29               2.0        3.0               13.0            8.0
# 1   31               NaN        NaN                NaN            NaN

# %%
dataset1[['TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']].mode()
# Out:
#    TotalWorkingYears  YearsAtCompany  YearsSinceLastPromotion  \
# 0                1.0               1                        0
#
#    YearsWithCurrManager
# 0                     0

# %%
dataset1[['Age','DistanceFromHome','Education','PercentSalaryHike','StandardHours']].skew()
# Out:
# Age                  0.712699
# DistanceFromHome     0.964420
# Education           -0.216055
# PercentSalaryHike    0.763693
# StandardHours        0.000000
# dtype: float64

# %%
dataset1[['TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']].skew()
# Out:
# TotalWorkingYears          1.679324
# YearsAtCompany             2.670876
# YearsSinceLastPromotion    2.208164
# YearsWithCurrManager       1.025486
# dtype: float64

# %%
dataset1[['Age','DistanceFromHome','Education','PercentSalaryHike','StandardHours']].kurt()
# Out:
# Age                 -0.073144
# DistanceFromHome    -0.041771
# Education           -0.616494
# PercentSalaryHike   -0.418411
# StandardHours        0.000000
# dtype: float64

# %%
dataset1[['TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']].kurt()
# Out:
# TotalWorkingYears          3.703175
# YearsAtCompany             9.456107
# YearsSinceLastPromotion    4.775929
# YearsWithCurrManager       0.242923
# dtype: float64

# %% [markdown]
# ## Hypothesis Statements

# %% [markdown]
# __Employees with the mean education of 2.8 years and standard deviation of 1.01 has the highest number of attrition__

# %% [markdown]
# __Employees with the mean age of 33.6 and standard deviation of 9.67 has the highest number of attrition__

# %% [markdown]
# __Employees with the mean Distance from home as 9.01 and standard deviation of 7 has the highest number of attrition__

# %% [markdown]
# __Employees with the mean Percent Salary Hike as 15.48 and standard deviation of 3.77 has the highest number of attrition__

# %% [markdown]
# __Employees who are 29 years old has higher number of attrition compared to others__

# %% [markdown]
# __Employees who has 1 year of experience with the compary has higher number of attritions__

# %% [markdown]
# __Employees with the mean Years at company as 5.13 and standard deviation of 5.94 has the highest number of attrition__

# %% [markdown]
# __Employees who get salary hike of 13% has highest number of attrition__

# %% [markdown]
# __Employees who live 2 kms away from the office has the highest number of attrition__

# %% [markdown]
# __Employees with the total working experience of 1 year has the higher number of attrition__
