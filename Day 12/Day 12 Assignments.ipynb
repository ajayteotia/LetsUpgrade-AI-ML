# %% [markdown]
# ## Parametric and Non-Parametric Test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_excel("dataset_yes.xlsx")
dataset
# Out:
#      Age  Attrition     BusinessTravel              Department  \
# 0     31          1  Travel_Frequently  Research & Development
# 1     28          1      Travel_Rarely  Research & Development
# 2     47          1         Non-Travel  Research & Development
# 3     44          1  Travel_Frequently  Research & Development
# 4     26          1      Travel_Rarely  Research & Development
# ..   ...        ...                ...                     ...
# 706   29          1      Travel_Rarely  Research & Development
# 707   33          1      Travel_Rarely                   Sales
# 708   33          1      Travel_Rarely                   Sales
# 709   32          1      Travel_Rarely                   Sales
# 710   37          1  Travel_Frequently                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                  10          1  Life Sciences              1           2
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Wilcoxon Test

# %% [markdown]
# ### H0 = There is no significant difference between Attrition rate and Employee's Distance from home ###
# ### H1 = There is a significant difference between Attrition rate and Employee's Distance from home  ###

# %%
from scipy.stats import wilcoxon
stats,p = wilcoxon(dataset.Attrition,dataset.DistanceFromHome)
print(stats,p)
# Out:
# 0.0 1.278803623384584e-102

# %% [markdown]
# ### Value of p is less than 0.05. Hence, we will reject the null hypothesis ###

# %% [markdown]
# ## Friedman Test

# %% [markdown]
# ### H0 = There is no significant difference between Attrition rate and Employee's Education and Age ###
# ### H1 = There is a significant difference between Attrition rate and Employee's Education and Age  ###

# %%
from scipy.stats import friedmanchisquare
stats,p = friedmanchisquare(dataset.Attrition,dataset.Age,dataset.Education)
print(stats,p)
# Out:
# 1386.2993492407804 9.309389028234066e-302

# %% [markdown]
# ### Value of p is less than 0.05. Hence, we will reject the null hypothesis ###

# %%
dataset1 = pd.read_csv("general_data.csv")
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset2 = dataset1.dropna()

# %% [markdown]
# ## Chi Square Test

# %% [markdown]
# ### H0 = There is no dependency between Attrition rate and Employee's Department ###
# ### H1 = There is dependency between Attrition rate and Employee's Department  ###

# %%
from scipy.stats import chi2_contingency
chitable = pd.crosstab(dataset2.Attrition,dataset2.Department)
chitable
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                      132                    2416   1129
# Yes                      55                     449    201

# %%
stats,p,dof,expected = chi2_contingency(chitable)
print(stats,p)
# Out:
# 25.89432541916022 2.382970570769315e-06

# %% [markdown]
# ### Value of p is less than 0.05. Hence, we will reject the null hypothesis ###

# %% [markdown]
# ## Mann Whitney Test

# %%
from scipy.stats import pearsonr
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
dataset["Gender"] = le.fit_transform(dataset["Gender"])

dataset_male = dataset[dataset["Gender"] == "Male"]
dataset_female = dataset[dataset["Gender"] == "Female"]
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# ### H0 = There is no significant difference between Attrition rate of Male employee  and Female employee ###
# ### H1 = There is a significant difference between Attrition rate of Male employee  and Female employee  ###

# %%
from scipy.stats import mannwhitneyu
stats,p=mannwhitneyu(dataset.Gender,dataset.Gender)
print(stats,p)
# Out:
# 252760.5 0.4999693517041583

# %% [markdown]
# ### Value of p is more than 0.05. Hence, we will accept the null hypothesis ###

# %% [markdown]
# ## Kruskal Wallis Test

# %%
dataset["EducationField"] = le.fit_transform(dataset["EducationField"])

dataset_life = dataset[dataset["EducationField"] == "Life Sciences"]
dataset_med = dataset[dataset["EducationField"] == "Medical"]
dataset_other = dataset[dataset["EducationField"] == "Other"]
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# ### H0 = There is no significant difference between Attrition rate of Employee's Education Field ###
# ### H1 = There is a significant difference between Attrition rate of Employee's Education Field  ###

# %%
from scipy.stats import kruskal
stats,p=kruskal(dataset.EducationField,dataset.EducationField,dataset.EducationField)
print(stats,p)
# Out:
# -1.0226964537795678e-12 1.0

# %% [markdown]
# ### Value of p is more than 0.05. Hence, we will accept the null hypothesis ###

# %% [markdown]
# ## One Sample T Test

# %%
dataset.describe()
# Out:
#               Age  Attrition  DistanceFromHome   Education  EducationField  \
# count  711.000000      711.0        711.000000  711.000000      711.000000
# mean    33.607595        1.0          9.012658    2.877637        2.071730
# std      9.675693        0.0          7.772368    1.014233        1.289908
# min     18.000000        1.0          1.000000    1.000000        0.000000
# 25%     28.000000        1.0          2.000000    2.000000        1.000000
# 50%     32.000000        1.0          7.000000    3.000000        2.000000
# 75%     39.000000        1.0         15.000000    4.000000        3.000000
# max     58.000000        1.0         29.000000    5.000000        5.000000
#
#        EmployeeCount   EmployeeID      Gender    JobLevel  MonthlyIncome  \
# count          711.0   711.000000  711.000000  711.000000     711.000000
# mean             1.0  2191.767932    0.620253    2.037975   61682.616034
# ...

# %% [markdown]
# ### H0 = There is no significant difference between the mean of Employee's Distance from home against the population mean ###
# ### H1 = There is a significant difference between the mean of Employee's Distance from home against the population mean  ###

# %%
from scipy.stats import ttest_1samp
stats,p=ttest_1samp(dataset.DistanceFromHome,9)
print(stats,p)
# Out:
# 0.04342645458925275 0.9653737996643088

# %% [markdown]
# ### Value of p is more than 0.05. Hence, we will accept the null hypothesis ###

# %% [markdown]
# ## Two Sample Paired Test

# %% [markdown]
# ### H0 = There is no significant difference between the mean of Employee's Education and Education Field ###
# ### H1 = There is a significant difference between the mean of Employee's Education and Education Field  ###

# %%
from scipy.stats import ttest_rel
stats,p=ttest_rel(dataset.Education,dataset.EducationField)
print(stats,p)
# Out:
# 12.838317519112925 4.4789118231460164e-34

# %% [markdown]
# ### Value of p is less than 0.05. Hence, we will reject the null hypothesis ###

# %% [markdown]
# ## Two Sample T Test

# %% [markdown]
# ### H0 = There is no significant difference between the mean of Distance from home between Male employee and Female employee ###
# ### H1 = There is a significant difference between the mean of Distance from home between Male employee and Female employee  ###

# %%
from scipy.stats import ttest_ind
stats,p=ttest_ind(dataset.Gender,dataset.DistanceFromHome)
print(stats,p)
# Out:
# -28.735694488880846 1.5919614803761805e-143

# %% [markdown]
# ### Value of p is less than 0.05. Hence, we will reject the null hypothesis ###

# %%
dataset1 = pd.read_csv("general_data.csv")

# %%
from scipy.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset1["Attrition"] = le.fit_transform(dataset1["Attrition"])

# %% [markdown]
# ## One Way ANOVA Test

# %% [markdown]
# ### H0 = There is no significant impact on Attrition rate because of Employee's Education ###
# ### H1 = There is a significant impact on Attrition rate because of Employee's Education  ###

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('Attrition~C(Education)',dataset1).fit()
oneway = sm.stats.anova_lm(model,typ=2)
print(oneway)
# Out:
# C:\Users\lenovo\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
#                   sum_sq      df         F    PR(>F)
# C(Education)    0.762859     4.0  1.410492  0.227725
# Residual      595.606529  4405.0       NaN       NaN

# %% [markdown]
# ### Value of p is more than 0.05. Hence, we will accept the null hypothesis ###

# %% [markdown]
# ## Two Way ANOVA Test

# %% [markdown]
# ### H0 = There is no significant impact on Attrition rate because of Last year training time and Years at company ###
# ### H1 = There is a significant impact on Attrition rate because of Last year training time and Years at company ###

# %%
model = ols('Attrition~C(TrainingTimesLastYear)+C(YearsAtCompany)',dataset1).fit()
twoway = sm.stats.anova_lm(model,typ=2)
print(twoway)
# Out:
#                               sum_sq      df         F        PR(>F)
# C(TrainingTimesLastYear)    2.334983     6.0  3.060272  5.454966e-03
# C(YearsAtCompany)          37.965100    36.0  8.292960  1.959510e-41
# Residual                  555.335810  4367.0       NaN           NaN

# %% [markdown]
# ### Value of p is less than 0.05. Hence, we will reject the null hypothesis ###
